# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fmatcasici/analisis-visualizacion-python/blob/main/05-dash/notebook.ipynb)
#
# # Tema 05 · Dash
#
# **Duración:** 60 min — **Luis Basto Díaz**
#
# ---
#
# ## Objetivos
#
# - Objetivo 1
# - Objetivo 2
# - Objetivo 3
#
# ## Contenido
#
# _Completa aquí la teoría y ejemplos de este tema._

# %%
# Instala/importa librerías necesarias para este tema

# %% [markdown]
# ## Práctica guiada
#
# _Instrucciones de la actividad para los asistentes._

# %%
# Tu código aquí

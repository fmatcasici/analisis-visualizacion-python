# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fmatcasici/analisis-visualizacion-python/blob/main/04-plotly/notebook.ipynb)
#
# # Tema 04 · Plotly
#
# **Duración:** 60 min — **Luis Basto Díaz**
#
# ---
#
# ## Objetivos
#
# - Objetivo 1
# - Objetivo 2
# - Objetivo 3
#
# ## Contenido
#
# Plotly es la biblioteca de referencia para crear gráficas interactivas en Python. Sus figuras son HTML/JavaScript por debajo, lo que las hace perfectas para notebooks y aplicaciones web.

# %%
# Instala/importa librerías necesarias para este tema

# %% [markdown]
# ## Práctica guiada
#
# _Instrucciones de la actividad para los asistentes._

# %%
# Tu código aquí

# %% [markdown]
# ## Recursos adicionales
#
# - Documentación oficial de Plotly: https://plotly.com/python/
# - Galería de ejemplos de Plotly: https://plotly.com/python/plotly-express/
#
# _Instrucciones de la actividad para los asistentes._
